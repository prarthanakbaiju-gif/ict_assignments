# %% [markdown]
# # Assignment Question
# Do the following operation on Iris dataset:
# 1. Read the dataset to the python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('/content/iris (2).xls')
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
data.mean(numeric_only=True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
plt.figure(figsize=(15, 10))


plt.subplot(2, 2, 1)
sns.boxplot(x='Classification', y='SL', data=data)
plt.title('Sepal Length (SL) by Species')
# Out:
# Text(0.5, 1.0, 'Sepal Length (SL) by Species')

# %%
plt.subplot(2, 2, 2)
sns.boxplot(x='Classification', y='SW', data=data)
plt.title('Sepal Width (SW) by Species')
# Out:
# Text(0.5, 1.0, 'Sepal Width (SW) by Species')

# %%
plt.subplot(2, 2, 3)
sns.boxplot(x='Classification', y='PL', data=data)
plt.title('Petal Length (PL) by Species')
# Out:
# Text(0.5, 1.0, 'Petal Length (PL) by Species')
